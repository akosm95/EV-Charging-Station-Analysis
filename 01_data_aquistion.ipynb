# %% [markdown]
# ### 1. API Request and saving the data

# %%
# Import the requests library
import os
from dotenv import load_dotenv
import requests

load_dotenv()

URL = "https://api.openchargemap.io/v3/poi/?"
params = {
    "output": "json",
    "countrycode": "HU",
    "maxresults": 5000,
    "key": os.getenv("OCM_API_KEY")
}

# Get the data from the API
try:
    response = requests.get(URL, params=params, timeout=10)
    response.raise_for_status()
except requests.exceptions.RequestException as e:
    print(f"API Error: {e}")
data = response.json()

# %%
# Convert to DataFrame and print columns
import pandas as pd
df = pd.json_normalize(data) 
print(df.columns.tolist())
# Out:
# ['UserComments', 'PercentageSimilarity', 'MediaItems', 'IsRecentlyVerified', 'DateLastVerified', 'ID', 'UUID', 'ParentChargePointID', 'DataProviderID', 'DataProvidersReference', 'OperatorID', 'OperatorsReference', 'UsageTypeID', 'UsageCost', 'Connections', 'NumberOfPoints', 'GeneralComments', 'DatePlanned', 'DateLastConfirmed', 'StatusTypeID', 'DateLastStatusUpdate', 'MetadataValues', 'DataQualityLevel', 'DateCreated', 'SubmissionStatusTypeID', 'DataProvider.WebsiteURL', 'DataProvider.Comments', 'DataProvider.DataProviderStatusType.IsProviderEnabled', 'DataProvider.DataProviderStatusType.ID', 'DataProvider.DataProviderStatusType.Title', 'DataProvider.IsRestrictedEdit', 'DataProvider.IsOpenDataLicensed', 'DataProvider.IsApprovedImport', 'DataProvider.License', 'DataProvider.DateLastImported', 'DataProvider.ID', 'DataProvider.Title', 'OperatorInfo.WebsiteURL', 'OperatorInfo.Comments', 'OperatorInfo.PhonePrimaryContact', 'OperatorInfo.PhoneSecondaryContact', 'OperatorInfo.IsPrivateIndividual', 'OperatorInfo.AddressInfo', 'OperatorInfo.BookingURL', 'OperatorInfo.ContactEmail', 'OperatorInfo.FaultReportEmail', 'OperatorInfo.IsRestrictedEdit', 'OperatorInfo.ID', 'OperatorInfo.Title', 'UsageType.IsPayAtLocation', 'UsageType.IsMembershipRequired', 'UsageType.IsAccessKeyRequired', 'UsageType.ID', 'UsageType.Title', 'StatusType.IsOperational', 'StatusType.IsUserSelectable', 'StatusType.ID', 'StatusType.Title', 'SubmissionStatus.IsLive', 'SubmissionStatus.ID', 'SubmissionStatus.Title', 'AddressInfo.ID', 'AddressInfo.Title', 'AddressInfo.AddressLine1', 'AddressInfo.AddressLine2', 'AddressInfo.Town', 'AddressInfo.StateOrProvince', 'AddressInfo.Postcode', 'AddressInfo.CountryID', 'AddressInfo.Country.ISOCode', 'AddressInfo.Country.ContinentCode', 'AddressInfo.Country.ID', 'AddressInfo.Country.Title', 'AddressInfo.Latitude', 'AddressInfo.Longitude', 'AddressInfo.ContactTelephone1', 'AddressInfo.ContactTelephone2', 'AddressInfo.ContactEmail', 'AddressInfo.AccessComments', 'AddressInfo.RelatedURL', 'AddressInfo.Distance', 'AddressInfo.DistanceUnit', 'OperatorInfo']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 863 entries, 0 to 862
# Data columns (total 83 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   UserComments                                           165 non-null    object
#  1   PercentageSimilarity                                   0 non-null      object
#  2   MediaItems                                             304 non-null    object
#  3   IsRecentlyVerified                                     863 non-null    bool
#  4   DateLastVerified                                       863 non-null    object
#  5   ID                                                     863 non-null    int64
#  6   UUID                                                   863 non-null    object
#  7   ParentChargePointID                                    0 non-null      object
#  8   DataProviderID                                         863 non-null    int64
#  9   DataProvidersReference                                 0 non-null      object
#  10  OperatorID                                             851 non-null    float64
#  11  OperatorsReference                                     33 non-null     object
#  12  UsageTypeID                                            863 non-null    int64
#  13  UsageCost                                              635 non-null    object
#  14  Connections                                            863 non-null    object
#  15  NumberOfPoints                                         862 non-null    float64
#  16  GeneralComments                                        389 non-null    object
#  17  DatePlanned                                            0 non-null      object
#  18  DateLastConfirmed                                      0 non-null      object
#  19  StatusTypeID                                           863 non-null    int64
#  20  DateLastStatusUpdate                                   863 non-null    object
#  21  MetadataValues                                         0 non-null      object
#  22  DataQualityLevel                                       863 non-null    int64
#  23  DateCreated                                            863 non-null    object
#  24  SubmissionStatusTypeID                                 863 non-null    int64
#  25  DataProvider.WebsiteURL                                863 non-null    object
#  26  DataProvider.Comments                                  0 non-null      object
#  27  DataProvider.DataProviderStatusType.IsProviderEnabled  863 non-null    bool
#  28  DataProvider.DataProviderStatusType.ID                 863 non-null    int64
#  29  DataProvider.DataProviderStatusType.Title              863 non-null    object
#  30  DataProvider.IsRestrictedEdit                          863 non-null    bool
#  31  DataProvider.IsOpenDataLicensed                        863 non-null    bool
#  32  DataProvider.IsApprovedImport                          863 non-null    bool
#  33  DataProvider.License                                   863 non-null    object
#  34  DataProvider.DateLastImported                          0 non-null      object
#  35  DataProvider.ID                                        863 non-null    int64
#  36  DataProvider.Title                                     863 non-null    object
#  37  OperatorInfo.WebsiteURL                                607 non-null    object
#  38  OperatorInfo.Comments                                  192 non-null    object
#  39  OperatorInfo.PhonePrimaryContact                       31 non-null     object
#  40  OperatorInfo.PhoneSecondaryContact                     0 non-null      float64
#  41  OperatorInfo.IsPrivateIndividual                       787 non-null    object
#  42  OperatorInfo.AddressInfo                               0 non-null      float64
#  43  OperatorInfo.BookingURL                                2 non-null      object
#  44  OperatorInfo.ContactEmail                              52 non-null     object
#  45  OperatorInfo.FaultReportEmail                          12 non-null     object
#  46  OperatorInfo.IsRestrictedEdit                          605 non-null    object
#  47  OperatorInfo.ID                                        851 non-null    float64
#  48  OperatorInfo.Title                                     851 non-null    object
#  49  UsageType.IsPayAtLocation                              248 non-null    object
#  50  UsageType.IsMembershipRequired                         254 non-null    object
#  51  UsageType.IsAccessKeyRequired                          248 non-null    object
#  52  UsageType.ID                                           863 non-null    int64
#  53  UsageType.Title                                        863 non-null    object
#  54  StatusType.IsOperational                               863 non-null    bool
#  55  StatusType.IsUserSelectable                            863 non-null    bool
#  56  StatusType.ID                                          863 non-null    int64
#  57  StatusType.Title                                       863 non-null    object
#  58  SubmissionStatus.IsLive                                863 non-null    bool
#  59  SubmissionStatus.ID                                    863 non-null    int64
#  60  SubmissionStatus.Title                                 863 non-null    object
#  61  AddressInfo.ID                                         863 non-null    int64
#  62  AddressInfo.Title                                      863 non-null    object
#  63  AddressInfo.AddressLine1                               863 non-null    object
#  64  AddressInfo.AddressLine2                               112 non-null    object
#  65  AddressInfo.Town                                       855 non-null    object
#  66  AddressInfo.StateOrProvince                            598 non-null    object
#  67  AddressInfo.Postcode                                   761 non-null    object
#  68  AddressInfo.CountryID                                  863 non-null    int64
#  69  AddressInfo.Country.ISOCode                            863 non-null    object
#  70  AddressInfo.Country.ContinentCode                      863 non-null    object
#  71  AddressInfo.Country.ID                                 863 non-null    int64
#  72  AddressInfo.Country.Title                              863 non-null    object
#  73  AddressInfo.Latitude                                   863 non-null    float64
#  74  AddressInfo.Longitude                                  863 non-null    float64
#  75  AddressInfo.ContactTelephone1                          464 non-null    object
#  76  AddressInfo.ContactTelephone2                          95 non-null     object
#  77  AddressInfo.ContactEmail                               258 non-null    object
#  78  AddressInfo.AccessComments                             256 non-null    object
#  79  AddressInfo.RelatedURL                                 518 non-null    object
#  80  AddressInfo.Distance                                   0 non-null      object
#  81  AddressInfo.DistanceUnit                               863 non-null    int64
#  82  OperatorInfo                                           0 non-null      float64
# dtypes: bool(8), float64(8), int64(15), object(52)
# memory usage: 512.5+ KB

# %%
df.head()
# Out:
#   UserComments PercentageSimilarity MediaItems  IsRecentlyVerified  \
# 0         None                 None       None                True
# 1         None                 None       None                True
# 2         None                 None       None                True
# 3         None                 None       None                True
# 4         None                 None       None                True
#
#        DateLastVerified      ID                                  UUID  \
# 0  2025-06-16T19:34:00Z  313310  18DB6494-7E85-443E-9866-71BF17961E92
# 1  2025-06-07T13:14:00Z  313307  608051CB-030A-4B62-97EB-37DC1E5F3C43
# 2  2025-06-07T13:14:00Z  313306  D79B476C-35B2-4898-8901-2AE022D0F8B1
# 3  2025-06-07T13:09:00Z  313305  05118A01-18C7-48E7-8B58-438ABDD72FD1
# 4  2025-06-11T14:02:00Z  312979  8B5D4F6B-8F8D-401F-872B-D00E42F30805
#
#   ParentChargePointID  DataProviderID DataProvidersReference  ...  \
# 0                None               1                   None  ...
# 1                None               1                   None  ...
# 2                None               1                   None  ...
# 3                None               1                   None  ...
# 4                None               1                   None  ...
#
#    AddressInfo.Latitude AddressInfo.Longitude  AddressInfo.ContactTelephone1  \
# 0             47.677106             19.667077                           None
# 1             47.561080             19.049120                           None
# 2             47.383440             19.026830                           None
# 3             47.149650             18.431330                           None
# 4             46.926144             17.837953                   +36202882545
#
#   AddressInfo.ContactTelephone2 AddressInfo.ContactEmail  \
# 0                          None                     None
# 1                          None                     None
# 2                          None                     None
# 3                          None                     None
# 4                          None                     None
#
#    AddressInfo.AccessComments              AddressInfo.RelatedURL  \
# 0                        None                                None
# 1                        None                                None
# 2                        None                                None
# 3                        None                                None
# 4                        None  https://evdirect.hu/?page_id=49603
#
#   AddressInfo.Distance AddressInfo.DistanceUnit  OperatorInfo
# 0                 None                        0           NaN
# 1                 None                        0           NaN
# 2                 None                        0           NaN
# 3                 None                        0           NaN
# 4                 None                        0           NaN
#
# [5 rows x 83 columns]

# %%
df.tail()
# Out:
#                                           UserComments PercentageSimilarity  \
# 858  [{'ID': 19624, 'ChargePointID': 31615, 'Commen...                 None
# 859  [{'ID': 4434, 'ChargePointID': 31613, 'Comment...                 None
# 860  [{'ID': 14622, 'ChargePointID': 31195, 'Commen...                 None
# 861  [{'ID': 4432, 'ChargePointID': 31194, 'Comment...                 None
# 862                                               None                 None
#
#                                             MediaItems  IsRecentlyVerified  \
# 858  [{'ID': 15612, 'ChargePointID': 31615, 'ItemUR...               False
# 859  [{'ID': 1311, 'ChargePointID': 31613, 'ItemURL...               False
# 860  [{'ID': 1275, 'ChargePointID': 31195, 'ItemURL...               False
# 861  [{'ID': 1427, 'ChargePointID': 31194, 'ItemURL...               False
# 862                                               None               False
#
#          DateLastVerified     ID                                  UUID  \
# 858  2024-02-05T09:45:00Z  31615  83CF29C7-AD32-49A3-BFD0-384D1DB8AAB1
# 859  2024-02-05T09:45:00Z  31613  C5D4CCDE-DBB9-4699-8F23-FE840471DDD3
# 860  2016-12-31T09:29:00Z  31195  BB97B029-6851-4F50-88D6-0C24E45059E7
# 861  2024-02-05T09:45:00Z  31194  953DF5FC-60E2-4911-8ABA-C73C9756A0F7
# 862  2020-01-05T13:56:00Z  23660  E31104D0-50F0-4F1A-84B6-B7745E00D62A
#
#     ParentChargePointID  DataProviderID DataProvidersReference  ...  \
# 858                None               1                   None  ...
# 859                None               1                   None  ...
# 860                None               1                   None  ...
# 861                None               1                   None  ...
# 862                None               1                   None  ...
#
#      AddressInfo.Latitude AddressInfo.Longitude  \
# 858             47.465555             19.023444
# 859             47.464205             19.144451
# 860             47.561702             19.053664
# 861             47.501086             19.047113
# 862             46.535289             21.252083
#
#      AddressInfo.ContactTelephone1 AddressInfo.ContactTelephone2  \
# 858                 +36 80 200 897                          None
# 859                 +36 80 200 897                          None
# 860                           None                          None
# 861                 +36 80 200 897                          None
# 862                   +36309609550                   +3666240011
#
#     AddressInfo.ContactEmail  \
# 858                     None
# 859                     None
# 860                     None
# 861                     None
# 862          info@dmotors.hu
#
#                             AddressInfo.AccessComments  \
# 858                                               None
# 859  A P+R parkoló sorompón belüli részén. Belépésk...
# 860                                               None
# 861  A töltőoszlop nem a két parkoló között középen...
# 862                                               None
#
#                              AddressInfo.RelatedURL AddressInfo.Distance  \
# 858  https://www.eon.hu/hu/e-mobilitas/driveon.html                 None
# 859  https://www.eon.hu/hu/e-mobilitas/driveon.html                 None
# 860                                            None                 None
# 861  https://www.eon.hu/hu/e-mobilitas/driveon.html                 None
# 862                           http://www.dmotors.hu                 None
#
#     AddressInfo.DistanceUnit  OperatorInfo
# 858                        0           NaN
# 859                        0           NaN
# 860                        0           NaN
# 861                        0           NaN
# 862                        0           NaN
#
# [5 rows x 83 columns]

# %%
# Save the data to a CSV file
df.to_csv('ev_charging_data.csv', index=False)
